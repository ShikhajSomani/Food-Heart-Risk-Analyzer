# %%
import pandas as pd

# %%
df1 = pd.read_csv('food_nutrients\FOOD-DATA-GROUP1.csv')
df2 = pd.read_csv('food_nutrients\FOOD-DATA-GROUP2.csv')
df3 = pd.read_csv('food_nutrients\FOOD-DATA-GROUP3.csv')
df4 = pd.read_csv('food_nutrients\FOOD-DATA-GROUP4.csv')
df5 = pd.read_csv('food_nutrients\FOOD-DATA-GROUP5.csv')

# %%
nutrients_data = pd.concat([df1, df2, df3, df4, df5], ignore_index=True)

# %%
nutrients_data = nutrients_data[["food","Caloric Value","Fat","Saturated Fats","Sugars","Sodium"]]

# %%
nutrients_data.head()
# Out:
#                                food  Caloric Value   Fat  Saturated Fats  \
# 0                      cream cheese             51   5.0             2.9
# 1                 neufchatel cheese            215  19.4            10.9
# 2  requeijao cremoso light catupiry             49   3.6             2.3
# 3                    ricotta cheese             30   2.0             1.3
# 4              cream cheese low fat             30   2.3             1.4
#
#    Sugars  Sodium
# 0   0.500   0.016
# 1   2.700   0.300
# 2   3.400   0.000
# 3   0.091   0.017
# 4   0.900   0.046

# %%
nutrients_data.to_csv("nutrition_dataset.csv", index=False)
